# %%
# Dependencies
from config import API_KEY
import pandas as pd
import numpy as np
import requests
import json
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %% [markdown]
# # Get APIs data from JSearch for Data Analyst from every major cities from Australia
# ## Export as JSON data files

# %%
# Adelaide 

# Save url as variable
url = "https://jsearch.p.rapidapi.com/search"
# Set querystring
querystring = {"query":"Data Analyst in Adelaide, Australia","page":"1","num_pages":"20"}
# Set headers
headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}
# Make a GET request and save in variable
response = requests.get(url, headers=headers, params=querystring)
Ade_jsearch= response.json()

# Write data to a json file 
with open('../Resources/Adelaide_data_jsearch.json', 'w') as outfile:
	json.dump(Ade_jsearch, outfile, indent=4)

# %%
# Brisbane

url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Data Analyst in Brisbane, Australia","page":"1","num_pages":"20"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
Bris_jsearch = response.json()

# Write data to a json file 
with open('../Resources/Brisbane_data_jsearch.json', 'w') as outfile:
	json.dump(Bris_jsearch, outfile, indent=4)

# %%
# Canberra

url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Data Analyst in Canberra, Australia","page":"1","num_pages":"20"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
Canb_jsearch= response.json()

# Write data to a json file 
with open('../Resources/Canberra_data_jsearch.json', 'w') as outfile:
	json.dump(Canb_jsearch, outfile, indent=4)

# %%
# Darwin
url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Data Analyst in Darwin, Australia","page":"1","num_pages":"20"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
Darw_jsearch = response.json()

# Write data to a json file 
with open('../Resources/Darwin_data_jsearch.json', 'w') as outfile:
	json.dump(Darw_jsearch, outfile, indent=4)

# %%
# Hobart
url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Data Analyst in Hobart, Australia","page":"1","num_pages":"20"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
Hob_jsearch= response.json()

# Write data to a json file 
with open('../Resources/Hobart_data_jsearch.json', 'w') as outfile:
	json.dump(Hob_jsearch, outfile, indent=4)

# %%
# Melbourne
url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Data Analyst in Melbourne, Australia","page":"1","num_pages":"20"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
Melb_jsearch=response.json()

# Write data to a json file 
with open('../Resources/Melbourne_data_jsearch.json', 'w') as outfile:
	json.dump(Melb_jsearch, outfile, indent=4)

# %%
# Perth
url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Data Analyst in Perth, Australia","page":"1","num_pages":"20"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
Perth_jsearch=response.json()

# Write data to a json file 
with open('../Resources/Perth_data_jsearch.json', 'w') as outfile:
	json.dump(Perth_jsearch, outfile, indent=4)

# %%
# Sydney
url = "https://jsearch.p.rapidapi.com/search"

querystring = {"query":"Data Analyst in Sydney, Australia","page":"1","num_pages":"20"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "jsearch.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)
Syd_jsearch = response.json()

# Write data to a json file 
with open('../Resources/Sydney_data_jsearch.json', 'w') as outfile:
	json.dump(Syd_jsearch, outfile, indent=4)

# %% [markdown]
# ## Create clean data frame

# %%
# columns = ["employer_name","job_publisher","job_id","job_employment_type","job_title","job_apply_link",\
#     "job_description","job_posted_at_timestamp","job_posted_at_datetime_utc","job_city","job_state",\
#     "job_country","job_latitude","job_longitude","job_offer_expiration_datetime_utc","job_offer_expiration_timestamp",\
#     "job_required_experience","job_required_skills","job_required_education"]

# %%
# columns = ["employer_name","job_publisher","job_id","job_employment_type","job_title","job_apply_link",\
#     "job_description","job_city","job_state","job_latitude","job_longitude",
#     "job_required_experience","job_required_skills","job_required_education"]

# %%
# Select certain columns to be used and turn json file into a Pandas dataframe 
columns = ["employer_name","job_publisher","job_employment_type","job_title","job_apply_link",\
    "job_description","job_city","job_state","job_latitude","job_longitude",
    "job_required_education.bachelors_degree"]

# Adelaide
raw_Ade_df = pd.json_normalize(Ade_jsearch, 'data')
Ade_df = raw_Ade_df.loc[:, columns]
Ade_df.head(5)
# Out:
#            employer_name    job_publisher job_employment_type  \
# 0  Kelsian Group Limited         LinkedIn            FULLTIME
# 1                 Linkus      Trabajo.org            FULLTIME
# 2              Woolworth  BeBee Australia            FULLTIME
# 3       Beach Energy Ltd         LinkedIn            FULLTIME
# 4              Medtronic  BeBee Australia            FULLTIME
#
#                                            job_title  \
# 0  Data & Analytics Specialist Adelaide - Permane...
# 1                           Entry level Data Analyst
# 2                                       Data Analyst
# 3            Data Analyst - Exploration & Subsurface
# 4               Principle Advanced Analytics Analyst
#
#                                       job_apply_link  \
# 0  https://au.linkedin.com/jobs/view/data-analyti...
# 1  https://au.trabajo.org/job-847-20231009-1f6e1f...
# 2  https://au.bebee.com/job/20231008-fe05e2e56340...
# 3  https://au.linkedin.com/jobs/view/data-analyst...
# 4  https://au.bebee.com/job/20231009-a257e0e9aba6...
#
#                                      job_description  job_city job_state  \
# 0  International Tourism And Transport Company\n\...  Adelaide        SA
# 1  Company Profile\n\nNote: After Applying , Chec...  Adelaide        SA
# 2  You shall find the IDA team very self-motivate...  Adelaide        SA
# 3  • ASX Listed Energy Company - Adelaide Head Of...  Adelaide        SA
# 4  Careers that Change Lives\n\nJoin the Global O...  Adelaide        SA
#
#    job_latitude  job_longitude  job_required_education.bachelors_degree
# 0    -34.928497      138.60074                                     True
# 1    -34.928497      138.60074                                    False
# 2    -34.928497      138.60074                                    False
# 3    -34.928497      138.60074                                     True
# 4    -34.928497      138.60074                                    False

# %%
# Brisbane
raw_Bris_df= pd.json_normalize(Bris_jsearch, 'data')
Bris_df = raw_Bris_df.loc[:, columns]
Bris_df.head(5)
# Out:
#              employer_name    job_publisher job_employment_type  \
# 0   UnitingCare Queensland         LinkedIn          CONTRACTOR
# 1                      PwC  BeBee Australia            FULLTIME
# 2  The State of Queensland      Trabajo.org            FULLTIME
# 3                Woolworth  BeBee Australia            FULLTIME
# 4           Mott MacDonald   Mott MacDonald            FULLTIME
#
#                              job_title  \
# 0                  Data Analyst - HRIS
# 1                       Data Analytics
# 2  Principal Business And Data Analyst
# 3                         Data Analyst
# 4                         Data Analyst
#
#                                       job_apply_link  \
# 0  https://au.linkedin.com/jobs/view/data-analyst...
# 1  https://au.bebee.com/job/20231009-6045f6a1a5b8...
# 2  https://au.trabajo.org/job-2233-20231009-b3bf7...
# 3  https://au.bebee.com/job/20231008-8b3ec2cda902...
# 4     https://www.mottmac.com/job/79148/data-analyst
#
#                                      job_description  job_city job_state  \
# 0  We are inviting applications for a 6-month con...  Brisbane       QLD
# 1  Line of Service\n\nAssurance\n\nIndustry/Secto...  Brisbane       QLD
# 2  Are you looking for a challenging and rewardin...  Brisbane       QLD
# 3  You shall find the IDA team very self-motivate...  Brisbane       QLD
# 4  Job Description\nTogether, we open opportuniti...  Brisbane       QLD
#
#    job_latitude  job_longitude  job_required_education.bachelors_degree
# 0    -27.470453      153.02603                                     True
# 1    -27.470453      153.02603                                    False
# 2    -27.470453      153.02603                                    False
# 3    -27.470453      153.02603                                    False
# 4    -27.470453      153.02603                                    False

# %%
# Canberra
raw_Canb_df=pd.json_normalize(Canb_jsearch, 'data')
Canb_df=raw_Canb_df.loc[:, columns]
Canb_df.head(5)
# Out:
#                 employer_name job_publisher job_employment_type  \
# 0                       Modis         Modis          CONTRACTOR
# 1  Australian Taxation Office   SimplyHired            FULLTIME
# 2  Australian Taxation Office   SimplyHired            FULLTIME
# 3                         JLL      LinkedIn            FULLTIME
# 4  Australian Taxation Office   SimplyHired            FULLTIME
#
#               job_title                                     job_apply_link  \
# 0          Data Analyst  https://www.modis.com/en-au/jobs-iframe/job/ca...
# 1   Data Analyst - EL 1  https://www.simplyhired.com.au/job/zvqfaoAtAHe...
# 2  Data Analyst - APS 6  https://www.simplyhired.com.au/job/WjCSNYJMNpo...
# 3          Data Analyst  https://au.linkedin.com/jobs/view/data-analyst...
# 4  Data Analyst - APS 5  https://www.simplyhired.com.au/job/has2Fspvanp...
#
#                                      job_description  job_city job_state  \
# 0  One of our esteemed federal government clients...  Canberra       ACT
# 1  Smarter Data Program, various teams\n\nVarious...  Canberra       ACT
# 2  Smarter Data Program, various teams\n\nVarious...  Canberra       ACT
# 3  Shaping the future of real estate for a better...  Canberra       ACT
# 4  Smarter Data Program, various teams\n\nVarious...  Canberra       ACT
#
#    job_latitude  job_longitude  job_required_education.bachelors_degree
# 0    -35.280937         149.13                                    False
# 1    -35.280937         149.13                                    False
# 2    -35.280937         149.13                                    False
# 3    -35.280937         149.13                                     True
# 4    -35.280937         149.13                                    False

# %%
# Darwin
raw_Darw_df=pd.json_normalize(Darw_jsearch, 'data')
Darw_df= raw_Darw_df.loc[:, columns]
Darw_df.head(5)
# Out:
#                                employer_name    job_publisher  \
# 0  Department of Industry, Tourism and Trade      SimplyHired
# 1                                     Linkus      Trabajo.org
# 2                      face2face Recruitment         LinkedIn
# 3                                   Peroptyx  BeBee Australia
# 4              Northern Territory Government           Adzuna
#
#   job_employment_type               job_title  \
# 0            FULLTIME            Data Analyst
# 1            FULLTIME  Associate Data Analyst
# 2            FULLTIME     Senior Data Analyst
# 3            FULLTIME            Data Analyst
# 4            FULLTIME       Reporting Analyst
#
#                                       job_apply_link  \
# 0  https://www.simplyhired.com.au/job/pLl1MGkXPE6...
# 1  https://au.trabajo.org/job-847-20231009-ee4c66...
# 2  https://au.linkedin.com/jobs/view/senior-data-...
# 3  https://au.bebee.com/job/20231004-3fef234ae041...
# 4       https://www.adzuna.com.au/details/4321350774
#
#                                      job_description job_city job_state  \
# 0  Job description\n\nAgency Department of Indust...   Darwin        NT
# 1  Company Profile\n\nNote: After Applying , Chec...   Darwin        NT
# 2  • Closing Date: 13 October 2023, 9:00 AM\n\nfa...   Darwin        NT
# 3  For thousands of years, maps have provided hum...   Darwin        NT
# 4  The Reporting analyst will deliver objective, ...   Darwin        NT
#
#    job_latitude  job_longitude  job_required_education.bachelors_degree
# 0    -12.463734      130.84445                                    False
# 1    -12.463734      130.84445                                    False
# 2    -12.463734      130.84445                                     True
# 3    -12.463734      130.84445                                    False
# 4    -12.463734      130.84445                                    False

# %%
# Hobart
raw_Hob_df=pd.json_normalize(Hob_jsearch, 'data')
Hob_df=raw_Hob_df.loc[:, columns]
Hob_df.head(5)
# Out:
#            employer_name    job_publisher job_employment_type  \
# 0         Hydro Tasmania         LinkedIn            FULLTIME
# 1         Hydro Tasmania         Terra.do            FULLTIME
# 2              Woolworth  BeBee Australia            FULLTIME
# 3  face2face Recruitment         LinkedIn            FULLTIME
# 4               Randstad         Randstad            FULLTIME
#
#              job_title                                     job_apply_link  \
# 0         Data Analyst  https://au.linkedin.com/jobs/view/data-analyst...
# 1         Data Analyst  https://terra.do/climate-jobs/job-board/Data-A...
# 2         Data Analyst  https://au.bebee.com/job/20231008-0561cd38149b...
# 3  Senior Data Analyst  https://au.linkedin.com/jobs/view/senior-data-...
# 4    APS6 Data Analyst  https://www.randstad.com/jobs/aps6-data-analys...
#
#                                      job_description job_city job_state  \
# 0  • Data curious with a technical mind, includin...   Hobart       TAS
# 1  Hydro Tasmania has been at the forefront of cl...   Hobart       TAS
# 2  You shall find the IDA team very self-motivate...   Hobart       TAS
# 3  • Closing Date: 13 October 2023, 9:00 AM\n\nfa...   Hobart       TAS
# 4  APS6 Data Analyst\n\nAs an APS 6 Data Analyst,...   Hobart       TAS
#
#    job_latitude  job_longitude  job_required_education.bachelors_degree
# 0    -42.882607      147.32571                                     True
# 1    -42.882607      147.32571                                    False
# 2    -42.882607      147.32571                                    False
# 3    -42.882607      147.32571                                     True
# 4    -42.882607      147.32571                                    False

# %%
# Melbourne
raw_Melb_df=pd.json_normalize(Melb_jsearch, 'data')
Melb_df =raw_Melb_df.loc[:, columns]
Melb_df.head(5)
# Out:
#        employer_name           job_publisher job_employment_type  \
# 0           Peroptyx         BeBee Australia            FULLTIME
# 1                 EY              EY Careers            FULLTIME
# 2               Hays                 Denmark            FULLTIME
# 3  ACCIONA Australia                LinkedIn            FULLTIME
# 4          Arsenault  ZipRecruiter Australia            FULLTIME
#
#                                            job_title  \
# 0                                       Data Analyst
# 1  Expressions of Interest - Data Analyst, Data &...
# 2                                       Data Analyst
# 3                     Health and Safety Data Analyst
# 4                                Junior Data Analyst
#
#                                       job_apply_link  \
# 0  https://au.bebee.com/job/20231009-184636d12ead...
# 1  https://careers.ey.com/ey/job/Melbourne-Expres...
# 2  https://www.efinancialcareers.dk/jobs-Australi...
# 3  https://au.linkedin.com/jobs/view/health-and-s...
# 4  https://www.ziprecruiter.com.au/jobs/277348911...
#
#                                      job_description   job_city job_state  \
# 0  For thousands of years, maps have provided hum...  Melbourne       VIC
# 1  At EY, you’ll have the chance to build a caree...  Melbourne       VIC
# 2  See job description for details\n\nExcellent D...  Melbourne       VIC
# 3  The Opportunity\n\nWe have an exciting opportu...  Melbourne       VIC
# 4  Junior Data Analyst\n• Hybrid and Flexible Wor...  Melbourne       VIC
#
#    job_latitude  job_longitude  job_required_education.bachelors_degree
# 0     -37.81363      144.96306                                    False
# 1     -37.81363      144.96306                                    False
# 2     -37.81363      144.96306                                    False
# 3     -37.81363      144.96306                                     True
# 4     -37.81363      144.96306                                    False

# %%
# Perth 
raw_Perth_df=pd.json_normalize(Perth_jsearch, 'data')
Perth_df=raw_Perth_df.loc[:, columns]
Perth_df.head(5)
# Out:
#                            employer_name    job_publisher job_employment_type  \
# 0            Pyramid Global Technologies  BeBee Australia            FULLTIME
# 1                                Bonfire         LinkedIn            FULLTIME
# 2  Western Australian Institute of Sport         LinkedIn            FULLTIME
# 3                                 Ventia  BeBee Australia            FULLTIME
# 4                              Fortescue         LinkedIn            FULLTIME
#
#            job_title                                     job_apply_link  \
# 0  Data Analyst Lead  https://au.bebee.com/job/20231010-e8c87a47556c...
# 1       Data Analyst  https://au.linkedin.com/jobs/view/data-analyst...
# 2       Data Analyst  https://au.linkedin.com/jobs/view/data-analyst...
# 3       Data Analyst  https://au.bebee.com/job/20231005-dd48f477d4fd...
# 4     Data Scientist  https://au.linkedin.com/jobs/view/data-scienti...
#
#                                      job_description job_city job_state  \
# 0  About the job Data Analyst Lead\n\nAn Analytic...    Perth        WA
# 1  Bonfire isn’t just another digital marketing a...    Perth        WA
# 2  Data Analyst\n\nAre you a Data Analyst who is ...    Perth        WA
# 3  We are looking for a creative Data Analyst to ...    Perth        WA
# 4  About Us\n\nFortescue is both a proud West Aus...    Perth        WA
#
#    job_latitude  job_longitude  job_required_education.bachelors_degree
# 0    -31.952312     115.861305                                    False
# 1    -31.952312     115.861305                                     True
# 2    -31.952312     115.861305                                     True
# 3    -31.952312     115.861305                                    False
# 4    -31.952312     115.861305                                     True

# %%
# Sydney
raw_Syd_df= pd.json_normalize(Syd_jsearch, 'data')
Syd_df = raw_Syd_df.loc[:, columns]
Syd_df.head(5)
# Out:
#               employer_name       job_publisher job_employment_type  \
# 0         Transport for NSW            LinkedIn            FULLTIME
# 1      Recruiters Worldwide            LinkedIn            FULLTIME
# 2             PWC Australia  PwC Australia Jobs            FULLTIME
# 3  Career Success Australia         Trabajo.org            FULLTIME
# 4      Recruiters Worldwide            LinkedIn            FULLTIME
#
#                                  job_title  \
# 0                     Spatial Data Analyst
# 1                             Data Analyst
# 2  Deals - Data Analyst | Senior Associate
# 3                             Data Analyst
# 4                             Data Analyst
#
#                                       job_apply_link  \
# 0  https://au.linkedin.com/jobs/view/spatial-data...
# 1  https://au.linkedin.com/jobs/view/data-analyst...
# 2  https://jobs-au.pwc.com/experiencedhires/au/en...
# 3  https://au.trabajo.org/job-2233-20231009-24345...
# 4  https://au.linkedin.com/jobs/view/data-analyst...
#
#                                      job_description job_city job_state  \
# 0  You’re agile, keen and open to meaningful work...   Sydney       NSW
# 1  Nestlé is looking for a Data Analyst.\n\n“Unlo...   Sydney       NSW
# 2  To solve important problems we need diverse ta...   Sydney       NSW
# 3  As a Data Analyst Intern, you will become part...   Sydney       NSW
# 4  Nestlé is looking for a Data Analyst.\n\n“Unlo...   Sydney       NSW
#
#    job_latitude  job_longitude  job_required_education.bachelors_degree
# 0     -33.86882      151.20929                                     True
# 1     -33.86882      151.20929                                     True
# 2     -33.86882      151.20929                                    False
# 3     -33.86882      151.20929                                    False
# 4     -33.86882      151.20929                                     True

# %% [markdown]
# ### Merge all cities and clean the data

# %%
# Add all the cities dataframes together and format column names
merge_df = pd.concat([Ade_df,Bris_df,Canb_df,Darw_df,Hob_df,Melb_df,Perth_df,Syd_df], axis =0)
# merge_df.columns = merge_df.columns.str.replace("_", " ").str.capitalize()
merge_df
# Out:
#              employer_name    job_publisher job_employment_type  \
# 0    Kelsian Group Limited         LinkedIn            FULLTIME
# 1                   Linkus      Trabajo.org            FULLTIME
# 2                Woolworth  BeBee Australia            FULLTIME
# 3         Beach Energy Ltd         LinkedIn            FULLTIME
# 4                Medtronic  BeBee Australia            FULLTIME
# ..                     ...              ...                 ...
# 145              GrainCorp         LinkedIn            FULLTIME
# 146                IT Pros       Talent.com            FULLTIME
# 147          Westpac Group  BeBee Australia            FULLTIME
# 148         I work for NSW         LinkedIn            FULLTIME
# 149       Salesforce, Inc.  BeBee Australia            FULLTIME
#
#                                              job_title  \
# 0    Data & Analytics Specialist Adelaide - Permane...
# 1                             Entry level Data Analyst
# 2                                         Data Analyst
# 3              Data Analyst - Exploration & Subsurface
# 4                 Principle Advanced Analytics Analyst
# ..                                                 ...
# 145                         Head of Analytics - Sydney
# 146  Online Data Research Analyst | Year 1 Ote $54,...
# 147                                            Analyst
# 148                                     Data Scientist
# 149                           Sales Operations Analyst
#
#                                         job_apply_link  \
# 0    https://au.linkedin.com/jobs/view/data-analyti...
# 1    https://au.trabajo.org/job-847-20231009-1f6e1f...
# 2    https://au.bebee.com/job/20231008-fe05e2e56340...
# 3    https://au.linkedin.com/jobs/view/data-analyst...
# 4    https://au.bebee.com/job/20231009-a257e0e9aba6...
# ..                                                 ...
# 145  https://au.linkedin.com/jobs/view/head-of-anal...
# 146         https://au.talent.com/view?id=f54edd4bc022
# 147  https://au.bebee.com/job/20231008-1ec414ebebdb...
# 148  https://au.linkedin.com/jobs/view/data-scienti...
# 149  https://au.bebee.com/job/20231007-ee2eb0f7b4cf...
#
#                                        job_description  job_city job_state  \
# 0    International Tourism And Transport Company\n\...  Adelaide        SA
# 1    Company Profile\n\nNote: After Applying , Chec...  Adelaide        SA
# 2    You shall find the IDA team very self-motivate...  Adelaide        SA
# 3    • ASX Listed Energy Company - Adelaide Head Of...  Adelaide        SA
# 4    Careers that Change Lives\n\nJoin the Global O...  Adelaide        SA
# ..                                                 ...       ...       ...
# 145  About the team\nWhat did you have for breakfas...    Sydney       NSW
# 146  Job Description Join us as a Data Research Ana...    Sydney       NSW
# 147  How will I help?\n\nAs a Analyst within the Ad...    Sydney       NSW
# 148  About Us\n\nThe NSW Institute of Sport [NSWIS]...    Sydney       NSW
# 149  Inc's Candidate Privacy Notice contains more d...    Sydney       NSW
#
#      job_latitude  job_longitude  job_required_education.bachelors_degree
# 0      -34.928497      138.60074                                     True
# 1      -34.928497      138.60074                                    False
# 2      -34.928497      138.60074                                    False
# 3      -34.928497      138.60074                                     True
# 4      -34.928497      138.60074                                    False
# ..            ...            ...                                      ...
# 145    -33.868820      151.20929                                     True
# 146    -33.868820      151.20929                                    False
# 147    -33.868820      151.20929                                    False
# 148    -33.868820      151.20929                                     True
# 149    -33.868820      151.20929                                    False
#
# [580 rows x 11 columns]

# %%
# clean data by replacing null with None and remove the \n from the data
jobsearch_df = merge_df.replace({np.NaN: None})
jobsearch_df = merge_df.replace({'\n': ' '}, regex=True)
jobsearch_df.reset_index(drop=True, inplace=True)
jobsearch_df.head(5)
# Out:
#            employer_name    job_publisher job_employment_type  \
# 0  Kelsian Group Limited         LinkedIn            FULLTIME
# 1                 Linkus      Trabajo.org            FULLTIME
# 2              Woolworth  BeBee Australia            FULLTIME
# 3       Beach Energy Ltd         LinkedIn            FULLTIME
# 4              Medtronic  BeBee Australia            FULLTIME
#
#                                            job_title  \
# 0  Data & Analytics Specialist Adelaide - Permane...
# 1                           Entry level Data Analyst
# 2                                       Data Analyst
# 3            Data Analyst - Exploration & Subsurface
# 4               Principle Advanced Analytics Analyst
#
#                                       job_apply_link  \
# 0  https://au.linkedin.com/jobs/view/data-analyti...
# 1  https://au.trabajo.org/job-847-20231009-1f6e1f...
# 2  https://au.bebee.com/job/20231008-fe05e2e56340...
# 3  https://au.linkedin.com/jobs/view/data-analyst...
# 4  https://au.bebee.com/job/20231009-a257e0e9aba6...
#
#                                      job_description  job_city job_state  \
# 0  International Tourism And Transport Company  A...  Adelaide        SA
# 1  Company Profile  Note: After Applying , Check ...  Adelaide        SA
# 2  You shall find the IDA team very self-motivate...  Adelaide        SA
# 3  • ASX Listed Energy Company - Adelaide Head Of...  Adelaide        SA
# 4  Careers that Change Lives  Join the Global Ope...  Adelaide        SA
#
#    job_latitude  job_longitude  job_required_education.bachelors_degree
# 0    -34.928497      138.60074                                     True
# 1    -34.928497      138.60074                                    False
# 2    -34.928497      138.60074                                    False
# 3    -34.928497      138.60074                                     True
# 4    -34.928497      138.60074                                    False

# %%
# convert dataframe into json final combine file
jobsearch_df.to_json('../Resources/finalcombine.json', indent=3)

# %%
# Export the DataFrame as a CSV file. 
jobsearch_df.to_csv("../Resources/finalcombinecsv.csv", encoding='utf8', index=False)

# %%
# Convert the data frame to HTML file
jobsearch_df.to_html('../templates/jobsearch.html',index=False)

# %% [markdown]
# # Import JSON file to SQLite database

# %%
import sqlite3
import json

# Connect to the SQLite database
conn = sqlite3.connect('JSearchdata.sqlite')
cursor = conn.cursor()

# Read JSON data from a file
with open('../Resources/finalcombine.json', 'r') as file:
    data = json.load(file)

# Ensure that data is a dictionary
if not isinstance(data, dict):
    raise ValueError("The JSON data should be a dictionary")

# Extract keys from the JSON data and convert to a list
keys = list(data.keys())

# Create a list of objects from the JSON data
objects = []
for i in range(len(data[keys[0]])):
    obj = {}
    for key in keys:
        # Replace periods with underscores in column names
        column_name = key.replace(".", "_")
        obj[column_name] = data[key][str(i)]
    objects.append(obj)

# Create the table based on the keys in the first object
if objects:
    first_item = objects[0]

    # Create the table with columns based on keys
    create_table_sql = f'''
        CREATE TABLE IF NOT EXISTS jobs (
            id INTEGER PRIMARY KEY,
            {', '.join([f'"{key}" TEXT' for key in first_item.keys()])}
        )
    '''
    cursor.execute(create_table_sql)

# Insert JSON data into the table
for item in objects:
    # Prepare column names and values for insertion
    columns = ', '.join(item.keys())
    values = ', '.join(['?'] * len(item))
    insert_sql = f'INSERT INTO jobs ({columns}) VALUES ({values})'
    cursor.execute(insert_sql, tuple(item.values()))

# Commit the changes and close the connection
conn.commit()
conn.close()
